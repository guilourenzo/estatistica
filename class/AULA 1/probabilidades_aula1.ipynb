# %%
import numpy as np

moeda = ['cara',  'coroa']
face = np.random.choice(moeda)

print('Face sorteada:', face)
# Out:
# Face sorteada: coroa

# %%
import numpy as np

moeda = ['cara',  'coroa']
n = 10

for i in range(0,n):
  face = np.random.choice(moeda)
  print('Face sorteada:', face)
# Out:
# Face sorteada: cara
# Face sorteada: cara
# Face sorteada: coroa
# Face sorteada: cara
# Face sorteada: coroa
# Face sorteada: cara
# Face sorteada: coroa
# Face sorteada: cara
# Face sorteada: coroa
# Face sorteada: coroa

# %%
import numpy as np

moeda = ['cara',  'coroa']
n = 10
ncaras = 0
for i in range(0,n):
  face = np.random.choice(moeda)
  if face == 'cara':
    ncaras = ncaras + 1
fa = ncaras/n
print('Frequência de caras:', fa)
# Out:
# Frequência de caras: 0.6

# %%
import numpy as np
import matplotlib.pyplot as plt

moeda = ['cara',  'coroa']
p = 0.5
lcaras = []
ln = []
for n in range(1,1000):
  ncaras = 0
  for i in range(0,n):
    face = np.random.choice(moeda)
    if face == 'cara':
      ncaras = ncaras + 1
  fa = ncaras/n
  lcaras.append(fa)
  ln.append(n)

plt.plot(ln,lcaras)
plt.axhline(y=p, color='r', linestyle='-')
plt.xlabel('Número de lançamentos')
plt.ylabel('Frequência de caras')
plt.show()

# %%
dado = [1,2,3,4,5,6]

n = 1000
vfaces = np.zeros(6)
for i in range(0,n):
  face = np.random.choice(dado)
  vfaces[face-1] = vfaces[face-1] + 1
print('Valor teórico:',1/6)
print("Frequencias obtidas:", vfaces/n)
# Out:
# Valor teórico: 0.16666666666666666
# Frequencias obtidas: [0.162 0.156 0.173 0.17  0.174 0.165]

# %%
import numpy as np
import matplotlib.pyplot as plt

moeda = ['cara','coroa', 'coroa','coroa','coroa','coroa','coroa','coroa','coroa','coroa']
p = 0
for m in moeda:
  if m == 'cara':
    p = p + 1
p = p/len(moeda)
print('p = ', p)

lcaras = []
ln = []
for n in range(1,1000):
  ncaras = 0
  for i in range(0,n):
    face = np.random.choice(moeda)
    if face == 'cara':
      ncaras = ncaras + 1
  fa = ncaras/n
  lcaras.append(fa)
  ln.append(n)
plt.plot(ln,lcaras)
plt.axhline(y=p, color='r', linestyle='-')
plt.xlabel('Número de lançamentos')
plt.ylabel('Frequência de caras')
plt.show()
# Out:
# p =  0.1

# %%
urna = ['V','V','V','V','V','A','A','A']
# A: sair uma bola azul
p = 0
for b in urna:
  if b == 'A':
    p = p + 1
p = p/len(urna)
print('p = ', p)

ns = 1000
sucessos = 0
for i in range(0,ns):
  bola = np.random.choice(urna)
  if bola == 'A':
    sucessos = sucessos + 1
fa = sucessos/ns
print('Frequência de sucessos:', fa)
# Out:
# p =  0.375
# Frequência de sucessos: 0.356
